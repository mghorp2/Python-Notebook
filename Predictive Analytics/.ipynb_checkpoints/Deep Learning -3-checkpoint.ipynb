# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt #For plotting
np.random.seed(0) #For repeatability of the experiment
from sklearn import cross_validation
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import warnings 
warnings.filterwarnings("ignore")

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j

pickle.dump(X,open('dataX.pickle','wb'))
pickle.dump(y,open('dataY.pickle','wb'))

# %%
#Plot the data
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %%
X.shape
# Out:
# (300, 2)

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# # Question 1

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 100 # size of hidden layer
W = 0.05 * np.random.randn(D,h)
b = np.zeros((1,h))
W_cv=W
b_cv=b

W2 = 0.05 * np.random.randn(h,K)
b2 = np.zeros((1,K))
W2_cv=W2
b2_cv=b2

# %%
# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

# %%
# gradient descent loop for relu
def grad_descent_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations):
    
    for i in range(iterations):

          # evaluate class scores, [N x K]
        hidden_layer = np.maximum(0, np.dot(xtrain, W) + b) # note, ReLU activation
        scores = np.dot(hidden_layer, W2) + b2

        # compute the class probabilities
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]

        # compute the loss: average cross-entropy loss and regularization
        corect_logprobs = -np.log(probs[range(num_examples),ytrain])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
#         if i % 5000 == 0:
#              print("iteration %d: loss %f" % (i, loss))

        # compute the gradient on scores
        dscores = probs
        dscores[range(num_examples),ytrain] -= 1
        dscores /= num_examples

          # backpropate the gradient to the parameters
        # first backprop into parameters W2 and b2
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        # next backprop into hidden layer
        dhidden = np.dot(dscores, W2.T)
        # backprop the ReLU non-linearity
        dhidden[hidden_layer <= 0] = 0
        # finally into W,b
        dW = np.dot(xtrain.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)

        # add regularization gradient contribution
        dW2 += reg * W2
        dW += reg * W

        # perform a parameter update
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2


    hidden_layer = np.maximum(0, np.dot(xtest, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    Accuracy=np.mean(predicted_class == ytest)
    #print('Accuracy: %.2f' % Accuracy)
    
           
    return W, W2,b,b2,Accuracy

# %%
W,W2,b,b2,Test_Accuracy = grad_descent_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations)
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# Test Accuracy: 0.98

# %%
h = 0.02
x_min, x_max = xtrain[:, 0].min() - 1, xtrain[:, 0].max() + 1
y_min, y_max = xtrain[:, 1].min() - 1, xtrain[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.maximum(0, np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b), W2) + b2
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()

# %% [markdown]
# #Cross-Validation Relu

# %%
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1
reg = 1e-4 # regularization strength
#Initial value for the Gradient Descent Parameter
step_size = 1e-1
iterations=10000
kfold = KFold(10)
validation_accuracy=[]
factor=[0.01,0.05,0.5,1]
np.random.seed(0)
for item in factor:
    W = item*np.random.randn(D,h)
    b = np.zeros((1,h))
    W2= item * np.random.randn(h,K)
    b2=np.zeros((1,K))
    for k,(train,test) in enumerate(kfold.split(X,y)):
        w_cv=W
        B_cv=b
        B2_cv=b2
        w2_cv=W2
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_relu(X[train], X[test], y[train], y[test],w_cv,w2_cv,B_cv,B2_cv,reg,step_size,num_examples,iterations)
        validation_accuracy.append(accuracy)
        #print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        #print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    print(item)
    print("Accuracy: %0.2f (+/- %0.2f)" % (np.mean(validation_accuracy), np.std(validation_accuracy) * 2))
# Out:
# 0.01
# Accuracy: 0.79 (+/- 0.56)
# 0.05
# Accuracy: 0.81 (+/- 0.54)
# 0.5
# Accuracy: 0.81 (+/- 0.55)
# 1
# Accuracy: 0.80 (+/- 0.55)

# %% [markdown]
# #sensitivity of the model's performance to different learning rates and the number of gradient descent iterations.

# %%
#Defining expand grid function 
import itertools
import pandas as pd

def expand_grid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Creating training grid
trainGrid = expand_grid({ 'num_iters':[100,200,1000,5000,10000],
                          'step_size': [1e-3,1e-2,1e-1,1e-0],
                         
                           #create a column to store accuracies in
                          'accuracy_mean': [0.0],
                         
                           #create a column to store accuract std's in
                          'accuracy_std' : [0.0] 
                        })
trainGrid['num_iters']= trainGrid['num_iters'].apply(lambda x: int(x))

# %%
for idx,item in trainGrid.iterrows():
    print(item)
    kfold = KFold(5)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    reg=1e-4
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_relu(X[train], X[test], y[train], y[test],W,W2,b,b2,reg,stepsize,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid.loc[idx,'accuracy_mean'], trainGrid.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# num_iters        100.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 0, dtype: float64
# Validation Accuracy for fold 0: 0.93
# done processing for k: 0
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.98
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.97 (+/- 0.06)
# **************
# num_iters        100.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 1, dtype: float64
# Validation Accuracy for fold 0: 0.85
# done processing for k: 0
# Validation Accuracy for fold 1: 0.88
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.80
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.91 (+/- 0.16)
# **************
# num_iters        100.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 2, dtype: float64
# Validation Accuracy for fold 0: 0.72
# done processing for k: 0
# Validation Accuracy for fold 1: 0.85
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.68
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.85 (+/- 0.27)
# **************
# num_iters        100.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 3, dtype: float64
# Validation Accuracy for fold 0: 0.32
# done processing for k: 0
# Validation Accuracy for fold 1: 0.42
# done processing for k: 1
# Validation Accuracy for fold 2: 0.67
# done processing for k: 2
# Validation Accuracy for fold 3: 0.58
# done processing for k: 3
# Validation Accuracy for fold 4: 0.78
# done processing for k: 4
# Accuracy: 0.55 (+/- 0.34)
# **************
# num_iters        200.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 4, dtype: float64
# Validation Accuracy for fold 0: 0.97
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 1.00
# done processing for k: 3
# Validation Accuracy for fold 4: 0.95
# done processing for k: 4
# Accuracy: 0.97 (+/- 0.06)
# **************
# num_iters        200.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 5, dtype: float64
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# Validation Accuracy for fold 1: 0.90
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        200.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 6, dtype: float64
# Validation Accuracy for fold 0: 0.80
# done processing for k: 0
# Validation Accuracy for fold 1: 0.87
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.73
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.88 (+/- 0.21)
# **************
# num_iters        200.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 7, dtype: float64
# Validation Accuracy for fold 0: 0.52
# done processing for k: 0
# Validation Accuracy for fold 1: 0.62
# done processing for k: 1
# Validation Accuracy for fold 2: 0.62
# done processing for k: 2
# Validation Accuracy for fold 3: 0.57
# done processing for k: 3
# Validation Accuracy for fold 4: 0.85
# done processing for k: 4
# Accuracy: 0.63 (+/- 0.23)
# **************
# num_iters        1000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 8, dtype: float64
# Validation Accuracy for fold 0: 0.95
# done processing for k: 0
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.95
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.97 (+/- 0.06)
# **************
# num_iters        1000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 9, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.88
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.92 (+/- 0.14)
# **************
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 10, dtype: float64
# Validation Accuracy for fold 0: 0.75
# done processing for k: 0
# Validation Accuracy for fold 1: 0.83
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.77
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.87 (+/- 0.21)
# **************
# num_iters        1000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 11, dtype: float64
# Validation Accuracy for fold 0: 0.35
# done processing for k: 0
# Validation Accuracy for fold 1: 0.28
# done processing for k: 1
# Validation Accuracy for fold 2: 0.63
# done processing for k: 2
# Validation Accuracy for fold 3: 0.47
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.37 (+/- 0.34)
# **************
# num_iters        5000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 12, dtype: float64
# Validation Accuracy for fold 0: 0.93
# done processing for k: 0
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.92
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.96 (+/- 0.07)
# **************
# num_iters        5000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 13, dtype: float64
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        5000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 14, dtype: float64
# Validation Accuracy for fold 0: 0.57
# done processing for k: 0
# Validation Accuracy for fold 1: 0.57
# done processing for k: 1
# Validation Accuracy for fold 2: 0.88
# done processing for k: 2
# Validation Accuracy for fold 3: 0.80
# done processing for k: 3
# Validation Accuracy for fold 4: 0.25
# done processing for k: 4
# Accuracy: 0.61 (+/- 0.44)
# **************
# num_iters        5000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 15, dtype: float64
# Validation Accuracy for fold 0: 0.20
# done processing for k: 0
# Validation Accuracy for fold 1: 0.20
# done processing for k: 1
# Validation Accuracy for fold 2: 0.50
# done processing for k: 2
# Validation Accuracy for fold 3: 0.30
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.27 (+/- 0.26)
# **************
# num_iters        10000.000
# step_size            0.001
# accuracy_mean        0.000
# accuracy_std         0.000
# Name: 16, dtype: float64
# Validation Accuracy for fold 0: 0.60
# done processing for k: 0
# Validation Accuracy for fold 1: 0.77
# done processing for k: 1
# Validation Accuracy for fold 2: 0.98
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 0.97
# done processing for k: 4
# Accuracy: 0.83 (+/- 0.28)
# **************
# num_iters        10000.00
# step_size            0.01
# accuracy_mean        0.00
# accuracy_std         0.00
# Name: 17, dtype: float64
# Validation Accuracy for fold 0: 0.53
# done processing for k: 0
# Validation Accuracy for fold 1: 0.50
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.78
# done processing for k: 3
# Validation Accuracy for fold 4: 0.97
# done processing for k: 4
# Accuracy: 0.76 (+/- 0.42)
# **************
# num_iters        10000.0
# step_size            0.1
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 18, dtype: float64
# Validation Accuracy for fold 0: 0.35
# done processing for k: 0
# Validation Accuracy for fold 1: 0.30
# done processing for k: 1
# Validation Accuracy for fold 2: 0.80
# done processing for k: 2
# Validation Accuracy for fold 3: 0.65
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.45 (+/- 0.49)
# **************
# num_iters        10000.0
# step_size            1.0
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 19, dtype: float64
# Validation Accuracy for fold 0: 0.13
# done processing for k: 0
# Validation Accuracy for fold 1: 0.18
# done processing for k: 1
# Validation Accuracy for fold 2: 0.53
# done processing for k: 2
# Validation Accuracy for fold 3: 0.22
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.24 (+/- 0.30)
# **************

# %%
print(trainGrid)
# Out:
#     num_iters  step_size  accuracy_mean  accuracy_std
# 0         100      0.001       0.133333      0.533333
# 1         100      0.010       0.016667      0.066667
# 2         100      0.100       0.230000      0.353648
# 3         100      1.000       0.296667      0.707547
# 4         200      0.001       0.923333      0.157198
# 5         200      0.010       0.893333      0.175879
# 6         200      0.100       0.780000      0.287827
# 7         200      1.000       0.466667      0.286744
# 8        1000      0.001       0.963333      0.064636
# 9        1000      0.010       0.913333      0.145144
# 10       1000      0.100       0.843333      0.256991
# 11       1000      1.000       0.360000      0.313120
# 12       5000      0.001       0.956667      0.071802
# 13       5000      0.010       0.926667      0.122202
# 14       5000      0.100       0.606667      0.370345
# 15       5000      1.000       0.236667      0.289367
# 16      10000      0.001       0.826667      0.324962
# 17      10000      0.010       0.776667      0.414514
# 18      10000      0.100       0.400000      0.412580
# 19      10000      1.000       0.233333      0.310555

# %%
N = len(trainGrid['num_iters'].unique())
ind = np.arange(N)
width = 0.14

fig = plt.figure(figsize = (12,6))
ax = fig.add_subplot(111)
x_001 = tuple(list(trainGrid[trainGrid['step_size'] == 0.001].accuracy_mean))
#x_001 = (0.98333300000000001, 0.98666699999999996, 0.96999999999999997, 0.95666700000000005, 0.89333300000000004)
rects1 = ax.bar(ind,x_001,width,color = 'g')

x_01 = trainGrid[trainGrid['step_size'] == 0.01].accuracy_mean
rects2 = ax.bar(ind+width,x_01,width,color= 'r')

x_1 = trainGrid[trainGrid['step_size'] == 0.1].accuracy_mean
rects3 = ax.bar(ind+(2*width),x_1,width,color = 'b')

x1 = trainGrid[trainGrid['step_size'] == 1].accuracy_mean
rects4 = ax.bar(ind+(3*width),x1,width,color = 'yellow')

ax.set_xlabel('Number of gradient descent iterations')
ax.set_ylabel('Accuracy')
ax.set_title('Models Accuracy w.r.t. different learning rates and gradient descent iterations')
ax.set_xticks(ind+width)
#ax.annotate()
ax.set_xticklabels(tuple(["{0:0.3f}".format(x) for x in (trainGrid.num_iters.unique())]))
ax.legend((rects1[0], rects2[0], rects3[0],rects4[0],), ('learning rate = 0.001', 'learning rate = 0.01','learning rate = 0.1','learning rate = 1'),
          loc='upper left', bbox_to_anchor=(1,1),ncol=1, fancybox=True, shadow=True)
#ax.annotate()

plt.show()

# %%
import itertools
import pandas as pd

def expandgrid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Question 6 : What is the sensitivity of the model’s performance to different regularization parameter values. Find the best 
#              regularization parameter using an exhaustive search procedure. Describe your choice via suitable plots. What is 
#              the performance difference between using regularization and no regularization?

#Using the best fit found in the last part, we'll try to find the best regularization parameter:

trainGrid_reg = expandgrid({ 'reg': [0.5,1e-1,1e-2,1e-4,1e-5,1e-6],
                              'num_iters':[10000],
                              'step_size': [1e-1],
                              'accuracy_mean': [0.0], #create a column to store accuracies in
                              'accuracy_std' : [0.0] #create a column to store accuract std's in
                        })

# %%
for idx,item in trainGrid_reg.iterrows():
    print(item)
    kfold = KFold(10)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    
    reg=int(item['reg'])
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_relu(X[train], X[test], y[train], y[test],W,W2,b,b2,reg,stepsize,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid_reg.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid_reg.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid_reg.loc[idx,'accuracy_mean'], trainGrid_reg.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# reg                  0.1
# num_iters        10000.0
# step_size            0.1
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 0, dtype: float64
# Validation Accuracy for fold 0: 0.73
# done processing for k: 0
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# Validation Accuracy for fold 6: 0.80
# done processing for k: 6
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# Validation Accuracy for fold 9: 1.00
# done processing for k: 9
# Accuracy: 0.94 (+/- 0.20)
# **************
# reg                  0.01
# num_iters        10000.00
# step_size            0.10
# accuracy_mean        0.00
# accuracy_std         0.00
# Name: 1, dtype: float64
# Validation Accuracy for fold 0: 0.80
# done processing for k: 0
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# Validation Accuracy for fold 6: 0.83
# done processing for k: 6
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# Validation Accuracy for fold 9: 1.00
# done processing for k: 9
# Accuracy: 0.95 (+/- 0.16)
# **************
# reg                  0.0001
# num_iters        10000.0000
# step_size            0.1000
# accuracy_mean        0.0000
# accuracy_std         0.0000
# Name: 2, dtype: float64
# Validation Accuracy for fold 0: 0.83
# done processing for k: 0
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# Validation Accuracy for fold 6: 0.83
# done processing for k: 6
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# Validation Accuracy for fold 9: 1.00
# done processing for k: 9
# Accuracy: 0.96 (+/- 0.14)
# **************
# reg                  0.00001
# num_iters        10000.00000
# step_size            0.10000
# accuracy_mean        0.00000
# accuracy_std         0.00000
# Name: 3, dtype: float64
# Validation Accuracy for fold 0: 0.83
# done processing for k: 0
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# Validation Accuracy for fold 6: 0.90
# done processing for k: 6
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# Validation Accuracy for fold 9: 1.00
# done processing for k: 9
# Accuracy: 0.96 (+/- 0.12)
# **************
# reg                  0.000001
# num_iters        10000.000000
# step_size            0.100000
# accuracy_mean        0.000000
# accuracy_std         0.000000
# Name: 4, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# Validation Accuracy for fold 6: 0.90
# done processing for k: 6
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# Validation Accuracy for fold 9: 1.00
# done processing for k: 9
# Accuracy: 0.97 (+/- 0.10)
# **************

# %%
trainGrid_reg
# Out:
#         reg  num_iters  step_size  accuracy_mean  accuracy_std
# 0  0.100000      10000        0.1       0.936667      0.198774
# 1  0.010000      10000        0.1       0.950000      0.155635
# 2  0.000100      10000        0.1       0.956667      0.136789
# 3  0.000010      10000        0.1       0.963333      0.117189
# 4  0.000001      10000        0.1       0.966667      0.103280

# %%
plt.plot(trainGrid_reg['reg'],trainGrid_reg['accuracy_mean'])
plt.xlabel('Regularization parameter')
plt.ylabel('Accuracy')
plt.title('Different Regularization parameters Vs Accuracy')
plt.show()

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.50)

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 100 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# %%
# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

# %%
W,W2,b,b2,Test_Accuracy = grad_descent_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098638
# iteration 5000: loss 0.240839
# Accuracy: 0.93
# Test Accuracy: 0.93

# %%
h = 0.02
x_min, x_max = xtrain[:, 0].min() - 1, xtrain[:, 0].max() + 1
y_min, y_max = xtrain[:, 1].min() - 1, xtrain[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.maximum(0, np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b), W2) + b2
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()

# %%
# gradient descent loop for relu
def grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations):
    
    for i in range(iterations):

          # evaluate class scores, [N x K]
        x=np.dot(xtrain, W) + b   
        alpha=0.01
        hidden_layer = np.maximum(alpha*x,x) # note, leaky ReLU activation
        scores = np.dot(hidden_layer, W2) + b2

        # compute the class probabilities
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]

        # compute the loss: average cross-entropy loss and regularization
        corect_logprobs = -np.log(probs[range(num_examples),ytrain])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
#         if i % 5000 == 0:
#              print("iteration %d: loss %f" % (i, loss))

        # compute the gradient on scores
        dscores = probs
        dscores[range(num_examples),ytrain] -= 1
        dscores /= num_examples

          # backpropate the gradient to the parameters
        # first backprop into parameters W2 and b2
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        # next backprop into hidden layer
        dhidden = np.dot(dscores, W2.T)
        # backprop the leaky ReLU non-linearity
        dhidden[hidden_layer <= 0] *= alpha
        # finally into W,b
        dW = np.dot(xtrain.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)

        # add regularization gradient contribution
        dW2 += reg * W2
        dW += reg * W

        # perform a parameter update
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2


    x_test=np.dot(xtest, W) + b
    hidden_layer = np.maximum(alpha * x_test, x_test)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    Accuracy=np.mean(predicted_class == ytest)
    #print('Accuracy: %.2f' % Accuracy)
    
           
    return W, W2,b,b2,Accuracy

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 150 # size of hidden layer
W = 0.05 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.05 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# %%
W2_cv=W2
b2_cv=b2
b_cv=b
W_cv=W

# %%
# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=5000

# %%
W,W2,b,b2,Test_Accuracy = grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# Test Accuracy: 0.92

# %%
h = 0.020
x_min, x_max = xtrain[:, 0].min() - 1, xtrain[:, 0].max() + 1
y_min, y_max = xtrain[:, 1].min() - 1, xtrain[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.maximum(0.01*(np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b), np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b), W2) + b2
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()

# %%
h=150
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1
reg = 1e-4 # regularization strength
#Initial value for the Gradient Descent Parameter
step_size = 1e-1
iterations=5000
kfold = KFold(10)
validation_accuracy=[]

factor=[0.01,0.05,0.5,1]
np.random.seed(0)
for item in factor:
    W = item*np.random.randn(D,h)
    b = np.zeros((1,h))
    W2= item * np.random.randn(h,K)
    b2=np.zeros((1,K))
    for k,(train,test) in enumerate(kfold.split(X,y)):
        w_cv=W
        B_cv=b
        B2_cv=b2
        w2_cv=W2
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_Leaky_relu(X[train], X[test], y[train], y[test],w_cv,w2_cv,B_cv,B2_cv,reg,step_size,num_examples,iterations)
        validation_accuracy.append(accuracy)
        #print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        #print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    print("Weight multipler: %0.2f"%(item))
    print("Accuracy: %0.2f (+/- %0.2f)" % (np.mean(validation_accuracy), np.std(validation_accuracy) * 2))
# Out:
# Weight multipler: 0.01
# Accuracy: 0.76 (+/- 0.59)
# Weight multipler: 0.05
# Accuracy: 0.80 (+/- 0.56)
# Weight multipler: 0.50
# Accuracy: 0.81 (+/- 0.55)
# Weight multipler: 1.00
# Accuracy: 0.81 (+/- 0.53)

# %%
#Defining expand grid function 
import itertools
import pandas as pd

def expand_grid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Creating training grid
trainGrid = expand_grid({ 'num_iters':[100,200,1000,5000,10000],
                          'step_size': [1e-3,1e-2,1e-1,1e-0],
                         
                           #create a column to store accuracies in
                          'accuracy_mean': [0.0],
                         
                           #create a column to store accuract std's in
                          'accuracy_std' : [0.0] 
                        })
trainGrid['num_iters']= trainGrid['num_iters'].apply(lambda x: int(x))

# %%
for idx,item in trainGrid.iterrows():
    print(item)
    kfold = KFold(5)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    reg=1e-4
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_Leaky_relu(X[train], X[test], y[train], y[test],W,W2,b,b2,reg,stepsize,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid.loc[idx,'accuracy_mean'], trainGrid.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# num_iters        100.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 0, dtype: float64
# Validation Accuracy for fold 0: 0.00
# done processing for k: 0
# Validation Accuracy for fold 1: 0.00
# done processing for k: 1
# Validation Accuracy for fold 2: 0.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.67
# done processing for k: 3
# Validation Accuracy for fold 4: 0.00
# done processing for k: 4
# Accuracy: 0.13 (+/- 0.53)
# **************
# num_iters        100.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 1, dtype: float64
# Validation Accuracy for fold 0: 0.00
# done processing for k: 0
# Validation Accuracy for fold 1: 0.00
# done processing for k: 1
# Validation Accuracy for fold 2: 0.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.08
# done processing for k: 3
# Validation Accuracy for fold 4: 0.00
# done processing for k: 4
# Accuracy: 0.02 (+/- 0.07)
# **************
# num_iters        100.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 2, dtype: float64
# Validation Accuracy for fold 0: 0.00
# done processing for k: 0
# Validation Accuracy for fold 1: 0.15
# done processing for k: 1
# Validation Accuracy for fold 2: 0.48
# done processing for k: 2
# Validation Accuracy for fold 3: 0.13
# done processing for k: 3
# Validation Accuracy for fold 4: 0.38
# done processing for k: 4
# Accuracy: 0.23 (+/- 0.35)
# **************
# num_iters        100.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 3, dtype: float64
# Validation Accuracy for fold 0: 0.00
# done processing for k: 0
# Validation Accuracy for fold 1: 0.07
# done processing for k: 1
# Validation Accuracy for fold 2: 0.98
# done processing for k: 2
# Validation Accuracy for fold 3: 0.23
# done processing for k: 3
# Validation Accuracy for fold 4: 0.20
# done processing for k: 4
# Accuracy: 0.30 (+/- 0.71)
# **************
# num_iters        200.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 4, dtype: float64
# Validation Accuracy for fold 0: 0.95
# done processing for k: 0
# Validation Accuracy for fold 1: 0.87
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 1.00
# done processing for k: 3
# Validation Accuracy for fold 4: 0.80
# done processing for k: 4
# Accuracy: 0.92 (+/- 0.16)
# **************
# num_iters        200.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 5, dtype: float64
# Validation Accuracy for fold 0: 0.83
# done processing for k: 0
# Validation Accuracy for fold 1: 0.83
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.80
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.89 (+/- 0.18)
# **************
# num_iters        200.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 6, dtype: float64
# Validation Accuracy for fold 0: 0.63
# done processing for k: 0
# Validation Accuracy for fold 1: 0.70
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.67
# done processing for k: 3
# Validation Accuracy for fold 4: 0.90
# done processing for k: 4
# Accuracy: 0.78 (+/- 0.29)
# **************
# num_iters        200.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 7, dtype: float64
# Validation Accuracy for fold 0: 0.50
# done processing for k: 0
# Validation Accuracy for fold 1: 0.23
# done processing for k: 1
# Validation Accuracy for fold 2: 0.68
# done processing for k: 2
# Validation Accuracy for fold 3: 0.47
# done processing for k: 3
# Validation Accuracy for fold 4: 0.45
# done processing for k: 4
# Accuracy: 0.47 (+/- 0.29)
# **************
# num_iters        1000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 8, dtype: float64
# Validation Accuracy for fold 0: 0.95
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.95
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.96 (+/- 0.06)
# **************
# num_iters        1000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 9, dtype: float64
# Validation Accuracy for fold 0: 0.85
# done processing for k: 0
# Validation Accuracy for fold 1: 0.88
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.91 (+/- 0.15)
# **************
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 10, dtype: float64
# Validation Accuracy for fold 0: 0.68
# done processing for k: 0
# Validation Accuracy for fold 1: 0.82
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.73
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.84 (+/- 0.26)
# **************
# num_iters        1000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 11, dtype: float64
# Validation Accuracy for fold 0: 0.40
# done processing for k: 0
# Validation Accuracy for fold 1: 0.30
# done processing for k: 1
# Validation Accuracy for fold 2: 0.62
# done processing for k: 2
# Validation Accuracy for fold 3: 0.35
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.36 (+/- 0.31)
# **************
# num_iters        5000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 12, dtype: float64
# Validation Accuracy for fold 0: 0.93
# done processing for k: 0
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.92
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.96 (+/- 0.07)
# **************
# num_iters        5000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 13, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.90
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.12)
# **************
# num_iters        5000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 14, dtype: float64
# Validation Accuracy for fold 0: 0.53
# done processing for k: 0
# Validation Accuracy for fold 1: 0.50
# done processing for k: 1
# Validation Accuracy for fold 2: 0.92
# done processing for k: 2
# Validation Accuracy for fold 3: 0.70
# done processing for k: 3
# Validation Accuracy for fold 4: 0.38
# done processing for k: 4
# Accuracy: 0.61 (+/- 0.37)
# **************
# num_iters        5000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 15, dtype: float64
# Validation Accuracy for fold 0: 0.13
# done processing for k: 0
# Validation Accuracy for fold 1: 0.17
# done processing for k: 1
# Validation Accuracy for fold 2: 0.52
# done processing for k: 2
# Validation Accuracy for fold 3: 0.23
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.24 (+/- 0.29)
# **************
# num_iters        10000.000
# step_size            0.001
# accuracy_mean        0.000
# accuracy_std         0.000
# Name: 16, dtype: float64
# Validation Accuracy for fold 0: 0.60
# done processing for k: 0
# Validation Accuracy for fold 1: 0.67
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# Validation Accuracy for fold 4: 0.97
# done processing for k: 4
# Accuracy: 0.83 (+/- 0.32)
# **************
# num_iters        10000.00
# step_size            0.01
# accuracy_mean        0.00
# accuracy_std         0.00
# Name: 17, dtype: float64
# Validation Accuracy for fold 0: 0.52
# done processing for k: 0
# Validation Accuracy for fold 1: 0.55
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.78 (+/- 0.41)
# **************
# num_iters        10000.0
# step_size            0.1
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 18, dtype: float64
# Validation Accuracy for fold 0: 0.28
# done processing for k: 0
# Validation Accuracy for fold 1: 0.30
# done processing for k: 1
# Validation Accuracy for fold 2: 0.67
# done processing for k: 2
# Validation Accuracy for fold 3: 0.62
# done processing for k: 3
# Validation Accuracy for fold 4: 0.13
# done processing for k: 4
# Accuracy: 0.40 (+/- 0.41)
# **************
# num_iters        10000.0
# step_size            1.0
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 19, dtype: float64
# Validation Accuracy for fold 0: 0.13
# done processing for k: 0
# Validation Accuracy for fold 1: 0.18
# done processing for k: 1
# Validation Accuracy for fold 2: 0.53
# done processing for k: 2
# Validation Accuracy for fold 3: 0.22
# done processing for k: 3
# Validation Accuracy for fold 4: 0.10
# done processing for k: 4
# Accuracy: 0.23 (+/- 0.31)
# **************

# %%
print(trainGrid)
# Out:
#     num_iters  step_size  accuracy_mean  accuracy_std
# 0         100      0.001       0.133333      0.533333
# 1         100      0.010       0.016667      0.066667
# 2         100      0.100       0.230000      0.353648
# 3         100      1.000       0.296667      0.707547
# 4         200      0.001       0.923333      0.157198
# 5         200      0.010       0.893333      0.175879
# 6         200      0.100       0.780000      0.287827
# 7         200      1.000       0.466667      0.286744
# 8        1000      0.001       0.963333      0.064636
# 9        1000      0.010       0.913333      0.145144
# 10       1000      0.100       0.843333      0.256991
# 11       1000      1.000       0.360000      0.313120
# 12       5000      0.001       0.956667      0.071802
# 13       5000      0.010       0.926667      0.122202
# 14       5000      0.100       0.606667      0.370345
# 15       5000      1.000       0.236667      0.289367
# 16      10000      0.001       0.826667      0.324962
# 17      10000      0.010       0.776667      0.414514
# 18      10000      0.100       0.400000      0.412580
# 19      10000      1.000       0.233333      0.310555

# %%
import itertools
import pandas as pd

def expandgrid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Question 6 : What is the sensitivity of the model’s performance to different regularization parameter values. Find the best 
#              regularization parameter using an exhaustive search procedure. Describe your choice via suitable plots. What is 
#              the performance difference between using regularization and no regularization?

#Using the best fit found in the last part, we'll try to find the best regularization parameter:

trainGrid_reg = expandgrid({ 'reg': np.arange(0, 1, 0.1),
                              'num_iters':[1000],
                              'step_size': [1e-1],
                              'accuracy_mean': [0.0], #create a column to store accuracies in
                              'accuracy_std' : [0.0] #create a column to store accuract std's in
                        })
trainGrid_reg
# Out:
#    reg  num_iters  step_size  accuracy_mean  accuracy_std
# 0  0.0       1000        0.1            0.0           0.0
# 1  0.1       1000        0.1            0.0           0.0
# 2  0.2       1000        0.1            0.0           0.0
# 3  0.3       1000        0.1            0.0           0.0
# 4  0.4       1000        0.1            0.0           0.0
# 5  0.5       1000        0.1            0.0           0.0
# 6  0.6       1000        0.1            0.0           0.0
# 7  0.7       1000        0.1            0.0           0.0
# 8  0.8       1000        0.1            0.0           0.0
# 9  0.9       1000        0.1            0.0           0.0

# %%
for idx,item in trainGrid_reg.iterrows():
    print(item)
    kfold = KFold(5)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    
    reg=int(item['reg'])
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        num_examples=X[train].shape[0]
        w,w2,b,b2,accuracy=grad_descent_Leaky_relu(X[train], X[test], y[train], y[test],W,W2,b,b2,reg,stepsize,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid_reg.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid_reg.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid_reg.loc[idx,'accuracy_mean'], trainGrid_reg.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# reg                 0.0
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 0, dtype: float64
# Validation Accuracy for fold 0: 0.32
# done processing for k: 0
# Validation Accuracy for fold 1: 0.53
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.75
# done processing for k: 3
# Validation Accuracy for fold 4: 0.85
# done processing for k: 4
# Accuracy: 0.69 (+/- 0.48)
# **************
# reg                 0.1
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 1, dtype: float64
# Validation Accuracy for fold 0: 0.75
# done processing for k: 0
# Validation Accuracy for fold 1: 0.78
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 0.97
# done processing for k: 4
# Accuracy: 0.87 (+/- 0.20)
# **************
# reg                 0.2
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 2, dtype: float64
# Validation Accuracy for fold 0: 0.82
# done processing for k: 0
# Validation Accuracy for fold 1: 0.88
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.90 (+/- 0.15)
# **************
# reg                 0.3
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 3, dtype: float64
# Validation Accuracy for fold 0: 0.85
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# Validation Accuracy for fold 4: 0.98
# done processing for k: 4
# Accuracy: 0.92 (+/- 0.13)
# **************
# reg                 0.4
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 4, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.85
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.13)
# **************
# reg                 0.5
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 5, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.12)
# **************
# reg                 0.6
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 6, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.12)
# **************
# reg                 0.7
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 7, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.12)
# **************
# reg                 0.8
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 8, dtype: float64
# Validation Accuracy for fold 0: 0.87
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.12)
# **************
# reg                 0.9
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 9, dtype: float64
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************

# %%
trainGrid_reg
# Out:
#    reg  num_iters  step_size  accuracy_mean  accuracy_std
# 0  0.0       1000        0.1       0.690000      0.481017
# 1  0.1       1000        0.1       0.866667      0.198886
# 2  0.2       1000        0.1       0.903333      0.151144
# 3  0.3       1000        0.1       0.916667      0.134990
# 4  0.4       1000        0.1       0.926667      0.127541
# 5  0.5       1000        0.1       0.930000      0.120000
# 6  0.6       1000        0.1       0.930000      0.120000
# 7  0.7       1000        0.1       0.930000      0.120000
# 8  0.8       1000        0.1       0.930000      0.120000
# 9  0.9       1000        0.1       0.933333      0.113529

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.50)

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 150 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# %%
# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

# %%
W,W2,b,b2,Test_Accuracy = grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098570
# iteration 5000: loss 0.232790
# Accuracy: 0.94
# Test Accuracy: 0.94

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.40)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 150 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
print(W.shape)

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

W,W2,b,b2,Test_Accuracy = grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# (2, 150)
# iteration 0: loss 1.098563
# iteration 5000: loss 0.246704
# Accuracy: 0.97
# Test Accuracy: 0.97

# %% [markdown]
# # Question 3

# %%
# gradient descent loop for relu
def grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations):
    
    for i in range(iterations):

          # evaluate class scores, [N x K]
        x1=np.dot(xtrain, W) + b   
        x2=np.dot(xtrain, W2) + b2  
        hidden_layer = np.maximum(x2,x1) # note, leaky ReLU activation
        #print(x2.shape)
        scores = np.dot(hidden_layer, W3) + b3
        #print(scores.shape)
        # compute the class probabilities
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]

        # compute the loss: average cross-entropy loss and regularization
        corect_logprobs = -np.log(probs[range(num_examples),ytrain])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)+0.5*reg*np.sum(W3*W3)
        loss = data_loss + reg_loss
#         if i % 5000 == 0:
#              print("iteration %d: loss %f" % (i, loss))

        # compute the gradient on scores
        dscores = probs
        dscores[range(num_examples),ytrain] -= 1
        dscores /= num_examples

          # backpropate the gradient to the parameters
        # first backprop into parameters W3 and b3
        dW3 = np.dot(hidden_layer.T, dscores)
        db3 = np.sum(dscores, axis=0, keepdims=True)
        
        # next backprop into hidden layer for W and b
        dhidden_1 = np.dot(dscores, W3.T)
        # backprop the leaky ReLU non-linearity
        dhidden_1[x1 < x2] = 0
        # finally into W,b
        dW = np.dot(xtrain.T, dhidden_1)
        db = np.sum(dhidden_1, axis=0, keepdims=True)
        
        # next backprop into hidden layer for W2 and b2
        dhidden_2 = np.dot(dscores, W3.T)
        # backprop the leaky ReLU non-linearity
        dhidden_2[x2 < x1] = 0
        # finally into W,b
        dW2 = np.dot(xtrain.T, dhidden_2)
        db2 = np.sum(dhidden_2, axis=0, keepdims=True)

        # add regularization gradient contribution
        dW3 += reg * W3
        dW2 += reg * W2
        dW += reg * W

        # perform a parameter update
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2
        W3 += -step_size * dW3
        b3 += -step_size * db3


    x_test_1=np.dot(xtest, W) + b
    x_test_2=np.dot(xtest, W2) + b2
    hidden_layer = np.maximum(x_test_2, x_test_1)
    scores = np.dot(hidden_layer, W3) + b3
    predicted_class = np.argmax(scores, axis=1)
    Accuracy=np.mean(predicted_class == ytest)
    #print('Accuracy: %.2f' % Accuracy)
    
           
    return W, W2,W3,b,b2,b3,Accuracy

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 100 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))

W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))

W_cv=W
b_cv=b
W2_cv=W2
b2_cv=b2
W3_cv=W3
b3_cv=b3

# %%
# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

# %%
W,W2,W3,b,b2,b3,Test_Accuracy = grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098591
# iteration 5000: loss 0.170387
# Accuracy: 0.98
# Test Accuracy: 0.98

# %%
h = 0.020
x_min, x_max = xtrain[:, 0].min() - 1, xtrain[:, 0].max() + 1
y_min, y_max = xtrain[:, 1].min() - 1, xtrain[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.maximum(np.dot(np.c_[xx.ravel(), yy.ravel()], W2) + b2, np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b), W3) + b3
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()

# %%
h=100
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1
reg = 1e-4 # regularization strength
#Initial value for the Gradient Descent Parameter
step_size = 1e-1
iterations=10000
kfold = KFold(10)
validation_accuracy=[]

factor=[0.01,0.05,0.5,1]
np.random.seed(0)
for item in factor:
    W = item * np.random.randn(D,h)
    b = np.zeros((1,h))

    W3 = item * np.random.randn(h,K)
    b3 = np.zeros((1,K))

    W2 = item * np.random.randn(D,h)
    b2 = np.zeros((1,h))
    for k,(train,test) in enumerate(kfold.split(X,y)):
        w_cv=W
        B_cv=b
        B2_cv=b2
        w2_cv=W2
        B3_cv=b3
        w3_cv=W3
        num_examples=X[train].shape[0]
        W,W2,W3,b,b2,b3,accuracy=grad_descent_maxout(X[train], X[test], y[train],y[test],w_cv,w2_cv,w3_cv,B_cv,B2_cv,B3_cv,reg,step_size,num_examples,iterations)
        validation_accuracy.append(accuracy)
        #print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        #print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    print(item)
    print("Accuracy: %0.2f (+/- %0.2f)" % (np.mean(validation_accuracy), np.std(validation_accuracy) * 2))
# Out:
# 0.01
# Accuracy: 0.76 (+/- 0.57)
# 0.05
# Accuracy: 0.78 (+/- 0.58)
# 0.5
# Accuracy: 0.78 (+/- 0.57)
# 1
# Accuracy: 0.77 (+/- 0.57)

# %%
reg = 1e-4 # regularization strength
#Initial value for the Gradient Descent Parameter
step_size = 1e-1
iterations=10000
kfold = KFold(10)
validation_accuracy=[]

for k,(train,test) in enumerate(kfold.split(X,y)):
    W = W_cv
    b = b_cv
    W2=W2_cv
    b2=b2_cv
    W3=W3_cv
    b3=b3_cv
    num_examples=X[train].shape[0]
    W,W2,W3,b,b2,b3,accuracy=grad_descent_maxout(X[train], X[test], y[train], y[test],W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations)
    validation_accuracy.append(accuracy)
    print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
    print('done processing for k: %d' % k)
    
#Avg_validation_accuracy.append(np.mean(validation_accuracy))
print("Accuracy: %0.2f (+/- %0.2f)" % (np.mean(validation_accuracy), np.std(validation_accuracy) * 2))
# Out:
# iteration 0: loss 0.226514
# iteration 5000: loss 0.041856
# Accuracy: 0.53
# Validation Accuracy for fold 0: 0.53
# done processing for k: 0
# iteration 0: loss 0.204083
# iteration 5000: loss 0.062074
# Accuracy: 1.00
# Validation Accuracy for fold 1: 1.00
# done processing for k: 1
# iteration 0: loss 0.064588
# iteration 5000: loss 0.061542
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.056564
# iteration 5000: loss 0.044642
# Accuracy: 0.73
# Validation Accuracy for fold 3: 0.73
# done processing for k: 3
# iteration 0: loss 0.138021
# iteration 5000: loss 0.061497
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# iteration 0: loss 0.062004
# iteration 5000: loss 0.061189
# Accuracy: 1.00
# Validation Accuracy for fold 5: 1.00
# done processing for k: 5
# iteration 0: loss 0.051604
# iteration 5000: loss 0.042235
# Accuracy: 0.57
# Validation Accuracy for fold 6: 0.57
# done processing for k: 6
# iteration 0: loss 0.153367
# iteration 5000: loss 0.060953
# Accuracy: 1.00
# Validation Accuracy for fold 7: 1.00
# done processing for k: 7
# iteration 0: loss 0.062192
# iteration 5000: loss 0.060628
# Accuracy: 1.00
# Validation Accuracy for fold 8: 1.00
# done processing for k: 8
# iteration 0: loss 0.063245
# iteration 5000: loss 0.060086
# Accuracy: 0.37
# Validation Accuracy for fold 9: 0.37
# done processing for k: 9
# Accuracy: 0.82 (+/- 0.47)

# %%
#Defining expand grid function 
import itertools
import pandas as pd

def expand_grid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Creating training grid
trainGrid = expand_grid({ 'num_iters':[100,200,1000,5000,10000],
                          'step_size': [1e-3,1e-2,1e-1,1e-0],
                         
                           #create a column to store accuracies in
                          'accuracy_mean': [0.0],
                         
                           #create a column to store accuract std's in
                          'accuracy_std' : [0.0] 
                        })
trainGrid['num_iters']= trainGrid['num_iters'].apply(lambda x: int(x))

# %%
for idx,item in trainGrid.iterrows():
    print(item)
    kfold = KFold(5)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    reg=1e-4
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        W3=W3_cv
        b3=b3_cv
        num_examples=X[train].shape[0]
        W,W2,W3,b,b2,b3,accuracy=grad_descent_maxout(X[train], X[test], y[train], y[test],W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid.loc[idx,'accuracy_mean'], trainGrid.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# num_iters        100.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 0, dtype: float64
# iteration 0: loss 0.521994
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.101286
# Accuracy: 0.95
# Validation Accuracy for fold 1: 0.95
# done processing for k: 1
# iteration 0: loss 0.080878
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.055021
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.097878
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.08)
# **************
# num_iters        100.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 1, dtype: float64
# iteration 0: loss 0.055220
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.098081
# Accuracy: 0.95
# Validation Accuracy for fold 1: 0.95
# done processing for k: 1
# iteration 0: loss 0.084477
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053814
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.098820
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.08)
# **************
# num_iters        100.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 2, dtype: float64
# iteration 0: loss 0.054122
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.097872
# Accuracy: 0.93
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# iteration 0: loss 0.085569
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053523
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.099376
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.08)
# **************
# num_iters        100.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 3, dtype: float64
# iteration 0: loss 0.053819
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.097818
# Accuracy: 0.93
# Validation Accuracy for fold 1: 0.93
# done processing for k: 1
# iteration 0: loss 0.086119
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053392
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.099668
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.08)
# **************
# num_iters        200.000
# step_size          0.001
# accuracy_mean      0.000
# accuracy_std       0.000
# Name: 4, dtype: float64
# iteration 0: loss 0.053685
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.112487
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.094500
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053362
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.112784
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# num_iters        200.00
# step_size          0.01
# accuracy_mean      0.00
# accuracy_std       0.00
# Name: 5, dtype: float64
# iteration 0: loss 0.054047
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.113190
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.095323
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053278
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.113506
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# num_iters        200.0
# step_size          0.1
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 6, dtype: float64
# iteration 0: loss 0.053904
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.113603
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.095804
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053233
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.114007
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# num_iters        200.0
# step_size          1.0
# accuracy_mean      0.0
# accuracy_std       0.0
# Name: 7, dtype: float64
# iteration 0: loss 0.053818
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.114016
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.096133
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.053203
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.114399
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# num_iters        1000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 8, dtype: float64
# iteration 0: loss 0.053758
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.155691
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.120608
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.054381
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.138150
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        1000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 9, dtype: float64
# iteration 0: loss 0.062938
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.156418
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.122509
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.054404
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.139184
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 10, dtype: float64
# iteration 0: loss 0.063567
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.157619
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.123553
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.054418
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.139634
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        1000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 11, dtype: float64
# iteration 0: loss 0.063872
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.158640
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.124267
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.054430
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.139966
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# num_iters        5000.000
# step_size           0.001
# accuracy_mean       0.000
# accuracy_std        0.000
# Name: 12, dtype: float64
# iteration 0: loss 0.064091
# Accuracy: 0.73
# Validation Accuracy for fold 0: 0.73
# done processing for k: 0
# iteration 0: loss 0.287338
# Accuracy: 0.55
# Validation Accuracy for fold 1: 0.55
# done processing for k: 1
# iteration 0: loss 0.397161
# Accuracy: 0.98
# Validation Accuracy for fold 2: 0.98
# done processing for k: 2
# iteration 0: loss 0.083466
# Accuracy: 0.83
# Validation Accuracy for fold 3: 0.83
# done processing for k: 3
# iteration 0: loss 0.182365
# Accuracy: 0.32
# Validation Accuracy for fold 4: 0.32
# done processing for k: 4
# Accuracy: 0.68 (+/- 0.46)
# **************
# num_iters        5000.00
# step_size           0.01
# accuracy_mean       0.00
# accuracy_std        0.00
# Name: 13, dtype: float64
# iteration 0: loss 0.953963
# Accuracy: 0.72
# Validation Accuracy for fold 0: 0.72
# done processing for k: 0
# iteration 0: loss 0.285635
# Accuracy: 0.52
# Validation Accuracy for fold 1: 0.52
# done processing for k: 1
# iteration 0: loss 0.414756
# Accuracy: 0.97
# Validation Accuracy for fold 2: 0.97
# done processing for k: 2
# iteration 0: loss 0.087803
# Accuracy: 0.82
# Validation Accuracy for fold 3: 0.82
# done processing for k: 3
# iteration 0: loss 0.184090
# Accuracy: 0.32
# Validation Accuracy for fold 4: 0.32
# done processing for k: 4
# Accuracy: 0.67 (+/- 0.46)
# **************
# num_iters        5000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 14, dtype: float64
# iteration 0: loss 0.967917
# Accuracy: 0.68
# Validation Accuracy for fold 0: 0.68
# done processing for k: 0
# iteration 0: loss 0.290051
# Accuracy: 0.50
# Validation Accuracy for fold 1: 0.50
# done processing for k: 1
# iteration 0: loss 0.416965
# Accuracy: 0.97
# Validation Accuracy for fold 2: 0.97
# done processing for k: 2
# iteration 0: loss 0.088822
# Accuracy: 0.82
# Validation Accuracy for fold 3: 0.82
# done processing for k: 3
# iteration 0: loss 0.184121
# Accuracy: 0.32
# Validation Accuracy for fold 4: 0.32
# done processing for k: 4
# Accuracy: 0.66 (+/- 0.46)
# **************
# num_iters        5000.0
# step_size           1.0
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 15, dtype: float64
# iteration 0: loss 0.971217
# Accuracy: 0.70
# Validation Accuracy for fold 0: 0.70
# done processing for k: 0
# iteration 0: loss 0.291591
# Accuracy: 0.50
# Validation Accuracy for fold 1: 0.50
# done processing for k: 1
# iteration 0: loss 0.417010
# Accuracy: 0.95
# Validation Accuracy for fold 2: 0.95
# done processing for k: 2
# iteration 0: loss 0.089226
# Accuracy: 0.82
# Validation Accuracy for fold 3: 0.82
# done processing for k: 3
# iteration 0: loss 0.184112
# Accuracy: 0.32
# Validation Accuracy for fold 4: 0.32
# done processing for k: 4
# Accuracy: 0.66 (+/- 0.45)
# **************
# num_iters        10000.000
# step_size            0.001
# accuracy_mean        0.000
# accuracy_std         0.000
# Name: 16, dtype: float64
# iteration 0: loss 0.972673
# iteration 5000: loss 0.041368
# Accuracy: 0.25
# Validation Accuracy for fold 0: 0.25
# done processing for k: 0
# iteration 0: loss 0.530035
# iteration 5000: loss 0.044004
# Accuracy: 0.32
# Validation Accuracy for fold 1: 0.32
# done processing for k: 1
# iteration 0: loss 0.979303
# iteration 5000: loss 0.064361
# Accuracy: 0.77
# Validation Accuracy for fold 2: 0.77
# done processing for k: 2
# iteration 0: loss 0.190694
# iteration 5000: loss 0.041578
# Accuracy: 0.72
# Validation Accuracy for fold 3: 0.72
# done processing for k: 3
# iteration 0: loss 0.248435
# iteration 5000: loss 0.062492
# Accuracy: 0.23
# Validation Accuracy for fold 4: 0.23
# done processing for k: 4
# Accuracy: 0.46 (+/- 0.47)
# **************
# num_iters        10000.00
# step_size            0.01
# accuracy_mean        0.00
# accuracy_std         0.00
# Name: 17, dtype: float64
# iteration 0: loss 2.462154
# iteration 5000: loss 0.041420
# Accuracy: 0.23
# Validation Accuracy for fold 0: 0.23
# done processing for k: 0
# iteration 0: loss 0.559733
# iteration 5000: loss 0.043989
# Accuracy: 0.32
# Validation Accuracy for fold 1: 0.32
# done processing for k: 1
# iteration 0: loss 1.001041
# iteration 5000: loss 0.064290
# Accuracy: 0.77
# Validation Accuracy for fold 2: 0.77
# done processing for k: 2
# iteration 0: loss 0.199984
# iteration 5000: loss 0.041537
# Accuracy: 0.72
# Validation Accuracy for fold 3: 0.72
# done processing for k: 3
# iteration 0: loss 0.248989
# iteration 5000: loss 0.062472
# Accuracy: 0.18
# Validation Accuracy for fold 4: 0.18
# done processing for k: 4
# Accuracy: 0.44 (+/- 0.50)
# **************
# num_iters        10000.0
# step_size            0.1
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 18, dtype: float64
# iteration 0: loss 2.466429
# iteration 5000: loss 0.041430
# Accuracy: 0.23
# Validation Accuracy for fold 0: 0.23
# done processing for k: 0
# iteration 0: loss 0.570331
# iteration 5000: loss 0.043955
# Accuracy: 0.32
# Validation Accuracy for fold 1: 0.32
# done processing for k: 1
# iteration 0: loss 1.008182
# iteration 5000: loss 0.064251
# Accuracy: 0.77
# Validation Accuracy for fold 2: 0.77
# done processing for k: 2
# iteration 0: loss 0.206202
# iteration 5000: loss 0.041516
# Accuracy: 0.73
# Validation Accuracy for fold 3: 0.73
# done processing for k: 3
# iteration 0: loss 0.242713
# iteration 5000: loss 0.062466
# Accuracy: 0.17
# Validation Accuracy for fold 4: 0.17
# done processing for k: 4
# Accuracy: 0.44 (+/- 0.51)
# **************
# num_iters        10000.0
# step_size            1.0
# accuracy_mean        0.0
# accuracy_std         0.0
# Name: 19, dtype: float64
# iteration 0: loss 2.464416
# iteration 5000: loss 0.041444
# Accuracy: 0.23
# Validation Accuracy for fold 0: 0.23
# done processing for k: 0
# iteration 0: loss 0.575556
# iteration 5000: loss 0.043928
# Accuracy: 0.32
# Validation Accuracy for fold 1: 0.32
# done processing for k: 1
# iteration 0: loss 1.014593
# iteration 5000: loss 0.064212
# Accuracy: 0.75
# Validation Accuracy for fold 2: 0.75
# done processing for k: 2
# iteration 0: loss 0.214386
# iteration 5000: loss 0.041491
# Accuracy: 0.73
# Validation Accuracy for fold 3: 0.73
# done processing for k: 3
# iteration 0: loss 0.244857
# iteration 5000: loss 0.062462
# Accuracy: 0.17
# Validation Accuracy for fold 4: 0.17
# done processing for k: 4
# Accuracy: 0.44 (+/- 0.50)
# **************

# %%
print(trainGrid)
# Out:
#     num_iters  step_size  accuracy_mean  accuracy_std
# 0         100      0.001       0.953333      0.082731
# 1         100      0.010       0.953333      0.082731
# 2         100      0.100       0.950000      0.084327
# 3         100      1.000       0.950000      0.084327
# 4         200      0.001       0.943333      0.093333
# 5         200      0.010       0.943333      0.093333
# 6         200      0.100       0.943333      0.093333
# 7         200      1.000       0.943333      0.093333
# 8        1000      0.001       0.933333      0.113529
# 9        1000      0.010       0.933333      0.113529
# 10       1000      0.100       0.933333      0.113529
# 11       1000      1.000       0.933333      0.113529
# 12       5000      0.001       0.683333      0.462361
# 13       5000      0.010       0.666667      0.456070
# 14       5000      0.100       0.656667      0.458306
# 15       5000      1.000       0.656667      0.450481
# 16      10000      0.001       0.456667      0.469799
# 17      10000      0.010       0.443333      0.495580
# 18      10000      0.100       0.443333      0.510163
# 19      10000      1.000       0.440000      0.501819

# %%
import itertools
import pandas as pd

def expandgrid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

# %%
# Question 6 : What is the sensitivity of the model’s performance to different regularization parameter values. Find the best 
#              regularization parameter using an exhaustive search procedure. Describe your choice via suitable plots. What is 
#              the performance difference between using regularization and no regularization?

#Using the best fit found in the last part, we'll try to find the best regularization parameter:

trainGrid_reg = expandgrid({ 'reg': np.arange(0, 1, 0.1),
                              'num_iters':[1000],
                              'step_size': [1e-1],
                              'accuracy_mean': [0.0], #create a column to store accuracies in
                              'accuracy_std' : [0.0] #create a column to store accuract std's in
                        })
trainGrid_reg
# Out:
#    reg  num_iters  step_size  accuracy_mean  accuracy_std
# 0  0.0       1000        0.1            0.0           0.0
# 1  0.1       1000        0.1            0.0           0.0
# 2  0.2       1000        0.1            0.0           0.0
# 3  0.3       1000        0.1            0.0           0.0
# 4  0.4       1000        0.1            0.0           0.0
# 5  0.5       1000        0.1            0.0           0.0
# 6  0.6       1000        0.1            0.0           0.0
# 7  0.7       1000        0.1            0.0           0.0
# 8  0.8       1000        0.1            0.0           0.0
# 9  0.9       1000        0.1            0.0           0.0

# %%
for idx,item in trainGrid_reg.iterrows():
    print(item)
    kfold = KFold(5)
    validation_accuracy=[]
    iterations=int(item['num_iters'])
    stepsize=item['step_size'] 
    
    reg=int(item['reg'])
    for k,(train,test) in enumerate(kfold.split(X,y)):
        W = W_cv
        b = b_cv
        W2=W2_cv
        b2=b2_cv
        W3=W3_cv
        b3=b3_cv
        num_examples=X[train].shape[0]
        W,W2,W3,b,b2,b3,accuracy=grad_descent_maxout(X[train], X[test], y[train], y[test],W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations)
        validation_accuracy.append(accuracy)
        print('Validation Accuracy for fold %d: %.2f' % (k, accuracy))
        print('done processing for k: %d' % k)
    
    #Avg_validation_accuracy.append(np.mean(validation_accuracy))
    trainGrid_reg.loc[idx,'accuracy_mean']=np.mean(validation_accuracy)
    trainGrid_reg.loc[idx,'accuracy_std']=np.std(validation_accuracy) * 2
    print("Accuracy: %0.2f (+/- %0.2f)" % (trainGrid_reg.loc[idx,'accuracy_mean'], trainGrid_reg.loc[idx,'accuracy_std']))
    print('**************')
# Out:
# reg                 0.0
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 0, dtype: float64
# iteration 0: loss 2.435055
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.128499
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.100308
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.026165
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.110917
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# reg                 0.1
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 1, dtype: float64
# iteration 0: loss 0.031238
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.117875
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.086294
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.022043
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.107248
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# reg                 0.2
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 2, dtype: float64
# iteration 0: loss 0.024461
# Accuracy: 0.88
# Validation Accuracy for fold 0: 0.88
# done processing for k: 0
# iteration 0: loss 0.109703
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.081254
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.020257
# Accuracy: 0.87
# Validation Accuracy for fold 3: 0.87
# done processing for k: 3
# iteration 0: loss 0.103183
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.93 (+/- 0.11)
# **************
# reg                 0.3
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 3, dtype: float64
# iteration 0: loss 0.021789
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.103676
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.078051
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.019015
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.098096
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# reg                 0.4
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 4, dtype: float64
# iteration 0: loss 0.020106
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.098307
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.075651
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.018071
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.094627
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# reg                 0.5
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 5, dtype: float64
# iteration 0: loss 0.018962
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.094225
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.074570
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.017321
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.091781
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# reg                 0.6
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 6, dtype: float64
# iteration 0: loss 0.018088
# Accuracy: 0.90
# Validation Accuracy for fold 0: 0.90
# done processing for k: 0
# iteration 0: loss 0.091621
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.072875
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.016705
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.089129
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.94 (+/- 0.09)
# **************
# reg                 0.7
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 7, dtype: float64
# iteration 0: loss 0.017384
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.089276
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.071587
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.016189
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.086764
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.09)
# **************
# reg                 0.8
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 8, dtype: float64
# iteration 0: loss 0.016816
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.087132
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.070711
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.015744
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.084972
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.09)
# **************
# reg                 0.9
# num_iters        1000.0
# step_size           0.1
# accuracy_mean       0.0
# accuracy_std        0.0
# Name: 9, dtype: float64
# iteration 0: loss 0.016343
# Accuracy: 0.92
# Validation Accuracy for fold 0: 0.92
# done processing for k: 0
# iteration 0: loss 0.085202
# Accuracy: 0.92
# Validation Accuracy for fold 1: 0.92
# done processing for k: 1
# iteration 0: loss 0.069293
# Accuracy: 1.00
# Validation Accuracy for fold 2: 1.00
# done processing for k: 2
# iteration 0: loss 0.015355
# Accuracy: 0.90
# Validation Accuracy for fold 3: 0.90
# done processing for k: 3
# iteration 0: loss 0.083290
# Accuracy: 1.00
# Validation Accuracy for fold 4: 1.00
# done processing for k: 4
# Accuracy: 0.95 (+/- 0.09)
# **************

# %%
trainGrid_reg
# Out:
#    reg  num_iters  step_size  accuracy_mean  accuracy_std
# 0  0.0       1000        0.1       0.933333      0.113529
# 1  0.1       1000        0.1       0.933333      0.113529
# 2  0.2       1000        0.1       0.933333      0.113529
# 3  0.3       1000        0.1       0.943333      0.093333
# 4  0.4       1000        0.1       0.943333      0.093333
# 5  0.5       1000        0.1       0.943333      0.093333
# 6  0.6       1000        0.1       0.943333      0.093333
# 7  0.7       1000        0.1       0.946667      0.087939
# 8  0.8       1000        0.1       0.946667      0.087939
# 9  0.9       1000        0.1       0.946667      0.087939

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.50)

# %%
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 100 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))

W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))

W_cv=W
b_cv=b
W2_cv=W2
b2_cv=b2
W3_cv=W3
b3_cv=b3

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

# %%
W,W2,W3,b,b2,b3,Test_Accuracy = grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098603
# iteration 5000: loss 0.159189
# Accuracy: 0.97
# Test Accuracy: 0.97

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.40)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 150 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
print(W.shape)

W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))

W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

W,W2,W3,b,b2,b3,Test_Accuracy = grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# (2, 150)
# iteration 0: loss 1.098631
# iteration 5000: loss 0.158732
# Accuracy: 0.97
# Test Accuracy: 0.97

# %% [markdown]
# # question 4

# %% [markdown]
# # number of hidden units much smaller h=5

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 5 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=5000

W,W2,b,b2,Test_Accuracy = grad_descent_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098660
# Accuracy: 0.60
# Test Accuracy: 0.60

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 5 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=5000

W,W2,b,b2,Test_Accuracy = grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098660
# Accuracy: 0.60
# Test Accuracy: 0.60

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 5 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
print(W.shape)

W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))

W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

W,W2,W3,b,b2,b3,Test_Accuracy = grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# (2, 5)
# iteration 0: loss 1.098669
# iteration 5000: loss 0.224792
# Accuracy: 0.88
# Test Accuracy: 0.88

# %% [markdown]
# # number of hidden units much smaller h=500

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 500 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
print(W.shape)

W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))

W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=10000

W,W2,W3,b,b2,b3,Test_Accuracy = grad_descent_maxout(xtrain, xtest, ytrain, ytest,W,W2,W3,b,b2,b3,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# (2, 500)
# iteration 0: loss 1.098565
# iteration 5000: loss 0.148687
# Accuracy: 1.00
# Test Accuracy: 1.00

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 500 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=5000

W,W2,b,b2,Test_Accuracy = grad_descent_Leaky_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098503
# Accuracy: 0.88
# Test Accuracy: 0.88

# %%
np.random.seed(0)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)
# Feedforward neural net model
np.random.seed(0)
D = xtrain.shape[1] #Number of features
K = max(ytrain)+1 #Number of classes assuming class index starts from 0
# Start with an initialize parameters randomly
h = 500 # size of hidden layer
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))

W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-4 # regularization strength
#For simplicity we will take the batch size to be the same as number of examples
num_examples = xtrain.shape[0]
#Initial value for the Gradient Descent Parameter
step_size = 1e-1 #Also called learning rate
iterations=5000

W,W2,b,b2,Test_Accuracy = grad_descent_relu(xtrain, xtest, ytrain, ytest,W,W2,b,b2,reg,step_size,num_examples,iterations) 
print('Test Accuracy: %.2f' % Test_Accuracy)
# Out:
# iteration 0: loss 1.098504
# Accuracy: 0.88
# Test Accuracy: 0.88
