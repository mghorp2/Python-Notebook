# %%
import json
import pandas as pd

# %%
get_hashtag=[]
for item in twitter_tweets_re:
    get_hashtag.append(re.findall('hashtag_\w+',item))
    
hashtag=sum(get_hashtag,[])

# without taking case into account
hashtag_count=dict((x,hashtag.count(x)) for x in set(hashtag))
hashtag_sorted=sorted(hashtag_count,key=hashtag_count.get,reverse=True)
top_hashtag={}
for r in hashtag_sorted[0:5]:
    top_hashtag[r]=hashtag_count[r]
print('Top 5 Hashtags:',top_hashtag) 

#changing all hashtags to lowercase
hashtag_lower=[]
for item in hashtag:
    hashtag_lower.append(item.lower())

hashtag_lower_count=dict((x,hashtag_lower.count(x)) for x in set(hashtag_lower))
hashtag_sorted_lower=sorted(hashtag_lower_count,key=hashtag_lower_count.get,reverse=True)
top_hashtag_lower={}
for r in hashtag_sorted_lower[0:5]:
    top_hashtag_lower[r]=hashtag_lower_count[r]
print('Top 5 Hashtags - Ignoring Cases:',top_hashtag_lower)

# %%
count_v.get_feature_names()
vocab1=count_v.vocabulary_
s= [re.search(r'hashtag_\w+',x).group(0) for x in vocab1.keys() if re.search(r'hashtag_\w+',x)]
hashtag={}
for item in s:
    col=vocab1[item]
    hashtag[item]=np.sum(X[:,col],axis=0)

hashtag_sorted=sorted(hashtag,key=hashtag.get,reverse=True)
hashtag_sorted
top_hashtag={}
for r in hashtag_sorted[0:5]:
    top_hashtag[r]=hashtag[r]
print('Top 5 Hashtags:',top_hashtag)
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2018-01-22 02:39:40
# 1           NaN        None 2018-01-22 02:39:35
# 2           NaN        None 2018-01-22 02:39:35
# 3           NaN        None 2018-01-22 02:39:30
# 4           NaN        None 2018-01-22 02:39:28
#
#                                             entities extended_entities  \
# 0  {'urls': [], 'user_mentions': [{'indices': [3,...               NaN
# 1  {'urls': [], 'user_mentions': [{'indices': [3,...               NaN
# 2  {'urls': [{'indices': [117, 140], 'expanded_ur...               NaN
# 3  {'urls': [], 'user_mentions': [{'indices': [3,...               NaN
# 4  {'urls': [], 'user_mentions': [{'indices': [3,...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  955268699325456389  955268699325456384
# 1               0      False  None  955268679591186432  955268679591186432
# ...
